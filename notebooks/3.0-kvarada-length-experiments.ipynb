# %%
import pandas as pd
import numpy as np
import os, sys 
sys.path.append(os.environ['HOME'] + '/src/models/')
from deeplearning_models import DLTextClassifier
from sklearn.model_selection import train_test_split
# Out:
# /home/vkolhatk/anaconda3/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Experiment 1
#
# Train: C3 Train
# Test: C3 Test

# %%
def run_dl_experiment(C3_train_df, 
                      C3_test_df, 
                      results_csv_path = os.environ['HOME'] + 'models/CNN_predictions.csv',                       
                      model = 'cnn'):


    """    
    """    
    X_train = C3_train_df['pp_comment_text'].astype(str)
    y_train = C3_train_df['constructive_binary']
    
    X_test = C3_test_df['pp_comment_text'].astype(str)
    y_test = C3_test_df['constructive_binary']
    
    dlclf = DLTextClassifier(X_train, y_train)
    
    if model.endswith('lstm'):
        dlclf.build_bilstm()
        
    elif model.endswith('cnn'): 
        dlclf.build_cnn()
        
    dlclf.train(X_train, y_train)
    print('\nTrain results: \n\n')
    dlclf.evaluate(X_train, y_train)
    
    print('\nTest results: \n\n')
    dlclf.evaluate(X_test, y_test)
    results_df = dlclf.write_model_scores_df(C3_test_df, results_csv_path)

# %% [markdown]
# ### Experiment 1
#
# - Train: C3 Train (80%)
# - Test: C3 Test (20%)

# %%
C3_train_df = pd.read_csv(os.environ['C3_TRAIN'])
C3_test_df = pd.read_csv(os.environ['C3_TEST'])

# %%
C3_test_df.shape
# Out:
# (2400, 73)

# %%
#run_dl_experiment(C3_train_df, 
#                  C3_test_df, 
#                  results_csv_path = os.environ['HOME'] + 'models/biLSTM_C3_test_predictions.csv', 
#                  model = 'lstm')

# %%
run_dl_experiment(C3_train_df, C3_test_df, model = 'cnn')
# Out:
# len of encoded docs:  9600
# Pad sequences (samples x time)
# Padded data shape: (9600, 100)
# Number of words not found in glove embeddings:  655
# Percentage non-zero elements:  0.9757530955461098
# Building CNN model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 100, 300)          8116500
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 100, 128)          76928
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 20, 128)           49280
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 4, 128)            65664
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,325,013
# Trainable params: 8,325,013
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Train on 8640 samples, validate on 960 samples
# Epoch 1/5
# 8640/8640 [==============================] - 4s 430us/step - loss: 0.2236 - acc: 0.9157 - val_loss: 0.2006 - val_acc: 0.9177
# Epoch 2/5
# 8640/8640 [==============================] - 3s 328us/step - loss: 0.1606 - acc: 0.9421 - val_loss: 0.1907 - val_acc: 0.9167
# Epoch 3/5
# 8640/8640 [==============================] - 3s 334us/step - loss: 0.0850 - acc: 0.9708 - val_loss: 0.2798 - val_acc: 0.9125
# Epoch 4/5
# 8640/8640 [==============================] - 3s 337us/step - loss: 0.0325 - acc: 0.9900 - val_loss: 0.4269 - val_acc: 0.9052
# Epoch 5/5
# 8640/8640 [==============================] - 3s 330us/step - loss: 0.0149 - acc: 0.9953 - val_loss: 0.4473 - val_acc: 0.9031
#
# Train results:
#
#
# len of encoded docs:  9600
# Pad sequences (samples x time)
# Padded data shape: (9600, 100)
# sklearn micro-F1-Score: 0.99
#
# Test results:
#
#
# len of encoded docs:  2400
# Pad sequences (samples x time)
# Padded data shape: (2400, 100)
# sklearn micro-F1-Score: 0.9145833333333333
# len of encoded docs:  2400
# Pad sequences (samples x time)
# Padded data shape: (2400, 100)
# Predictions file written:  /home/vkolhatk/dev/constructiveness/models/CNN_predictions.csv

# %% [markdown]
# ### Experiment 2
#
# - Train: C3_MINUS_LB + C3-LB train (80%)
# - Test: C3 Test

# %%
C3_train_df = pd.read_csv(os.environ['C3_MINUS_LB'])
C3_test_df = pd.read_csv(os.environ['C3_LB'])

# %%
C3_train_df.columns
# Out:
# Index(['comment_counter', 'pp_comment_text', 'constructive',
#        'constructive_binary'],
#       dtype='object')

# %%
feats = ['comment_counter', 'pp_comment_text', 'constructive']
LB_X_train, LB_X_test, LB_y_train, LB_y_test = train_test_split(C3_test_df[feats], C3_test_df['constructive_binary'], train_size = 0.80, random_state=1)
# Out:
# /home/vkolhatk/anaconda3/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
inter_df = pd.concat([LB_X_train, LB_y_train], axis = 1)

# %%
inter_df.head()
# Out:
#           comment_counter                                    pp_comment_text  \
# 705  source1_24211771_152  King Ralph and many of his supporters have die...
# 341   source1_26845638_31  canada did the right things during the economi...
# 662   source1_14853747_24  One would think Phil Fontaine would be more co...
# 577  source2_26842506_870  Makes you wonder what the Harper government wo...
# 671   source1_21138349_21  No one can tell me that there are n't plenty e...
#
#      constructive  constructive_binary
# 705           0.2                  0.0
# 341           0.6                  1.0
# 662           0.2                  0.0
# 577           0.2                  0.0
# 671           0.2                  0.0

# %%
C3_train_df.head()
# Out:
#         comment_counter                                    pp_comment_text  \
# 0   source1_26023945_62  And this Conservative strategy has produced th...
# 1  source1_24565777_106  I commend Harper for holding the debates outsi...
# 2  source1_28775443_136  What a joke Rachel Notley is . This is what wa...
# 3    source1_8996700_50  Do you need to write an essay to prove the poi...
# 4  source1_29405071_126  Rob Ford was no saint . He should never have b...
#
#    constructive  constructive_binary
# 0           1.0                  1.0
# 1           1.0                  1.0
# 2           1.0                  1.0
# 3           1.0                  1.0
# 4           1.0                  1.0

# %%
train_df = pd.concat([C3_train_df, inter_df])

# %%
train_df.shape
# Out:
# (11670, 4)

# %%
test_df = pd.concat([LB_X_test, LB_y_test], axis = 1)

# %%
run_dl_experiment(train_df, test_df, model = 'cnn')
# Out:
# len of encoded docs:  11670
# Pad sequences (samples x time)
# Padded data shape: (11670, 100)
# Number of words not found in glove embeddings:  795
# Percentage non-zero elements:  0.9729408165346568
# Building CNN model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 300)          8825100
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100, 300)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 98, 250)           225250
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 49, 250)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 47, 250)           187750
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 23, 250)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 21, 250)           187750
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 250)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               62750
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# activation_3 (Activation)    (None, 250)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 251
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 9,488,851
# Trainable params: 9,488,851
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Train on 10503 samples, validate on 1167 samples
# Epoch 1/5
# 10503/10503 [==============================] - 4s 383us/step - loss: 1.2796 - acc: 0.8904 - val_loss: 2.2934 - val_acc: 0.4901
# Epoch 2/5
# 10503/10503 [==============================] - 4s 346us/step - loss: 0.3188 - acc: 0.9273 - val_loss: 1.6296 - val_acc: 0.4979
# Epoch 3/5
# 10503/10503 [==============================] - 4s 342us/step - loss: 0.2758 - acc: 0.9344 - val_loss: 1.3891 - val_acc: 0.5021
# Epoch 4/5
# 10503/10503 [==============================] - 4s 343us/step - loss: 0.2596 - acc: 0.9359 - val_loss: 1.2421 - val_acc: 0.5107
# Epoch 5/5
# 10503/10503 [==============================] - 4s 341us/step - loss: 0.2477 - acc: 0.9395 - val_loss: 1.1318 - val_acc: 0.5261
#
# Train results:
#
#
# len of encoded docs:  11670
# Pad sequences (samples x time)
# Padded data shape: (11670, 100)
# sklearn micro-F1-Score: 0.8317909168808911
#
# Test results:
#
#
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# sklearn micro-F1-Score: 0.5575757575757576
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# Predictions file written:  /home/vkolhatk/dev/constructiveness/models/CNN_C3_test_predictions1.csv

# %%
run_dl_experiment(train_df, test_df, model = 'lstm')
# Out:
# len of encoded docs:  11670
# Pad sequences (samples x time)
# Padded data shape: (11670, 100)
# Number of words not found in glove embeddings:  795
# Percentage non-zero elements:  0.9729408165346568
# Building model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 100, 300)          8825100
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               439296
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 9,264,653
# Trainable params: 439,553
# Non-trainable params: 8,825,100
# _________________________________________________________________
# None
# Training...
# Train on 10503 samples, validate on 1167 samples
# Epoch 1/5
# 10503/10503 [==============================] - 77s 7ms/step - loss: 0.1318 - acc: 0.9500 - val_loss: 1.2711 - val_acc: 0.5356
# Epoch 2/5
# 10503/10503 [==============================] - 76s 7ms/step - loss: 0.0686 - acc: 0.9796 - val_loss: 1.4586 - val_acc: 0.5424
# Epoch 3/5
# 10503/10503 [==============================] - 76s 7ms/step - loss: 0.0617 - acc: 0.9826 - val_loss: 1.4866 - val_acc: 0.5630
# Epoch 4/5
# 10503/10503 [==============================] - 76s 7ms/step - loss: 0.0638 - acc: 0.9823 - val_loss: 1.3727 - val_acc: 0.5458
# Epoch 5/5
# 10503/10503 [==============================] - 76s 7ms/step - loss: 0.0586 - acc: 0.9830 - val_loss: 1.4964 - val_acc: 0.5596
#
# Train results:
#
#
# len of encoded docs:  11670
# Pad sequences (samples x time)
# Padded data shape: (11670, 100)
# sklearn micro-F1-Score: 0.9453299057412168
#
# Test results:
#
#
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# sklearn micro-F1-Score: 0.5606060606060606
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# Predictions file written:  /home/vkolhatk/dev/constructiveness/models/CNN_C3_test_predictions1.csv

# %% [markdown]
# ### Experiment 3
#
# - Train: LB Train (80%)
# - Test: LB test (20%)

# %%
LB_train_df = pd.concat([LB_X_train, LB_y_train], axis = 1)
LB_test_df = pd.concat([LB_X_test, LB_y_test], axis = 1)

# %%
run_dl_experiment(LB_train_df, LB_test_df, model = 'cnn')
# Out:
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# Number of words not found in glove embeddings:  72
# Percentage non-zero elements:  0.9909395556658807
# Building CNN model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 100, 300)          2417100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 100, 300)          0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 98, 250)           225250
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 49, 250)           0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 47, 250)           187750
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 23, 250)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 21, 250)           187750
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 250)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 250)               62750
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 250)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 250)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 251
# _________________________________________________________________
# activation_6 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 3,080,851
# Trainable params: 3,080,851
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Train on 1186 samples, validate on 132 samples
# Epoch 1/5
# 1186/1186 [==============================] - 1s 784us/step - loss: 5.4844 - acc: 0.5135 - val_loss: 2.7701 - val_acc: 0.5455
# Epoch 2/5
# 1186/1186 [==============================] - 0s 293us/step - loss: 1.7545 - acc: 0.5008 - val_loss: 1.1050 - val_acc: 0.4924
# Epoch 3/5
# 1186/1186 [==============================] - 0s 285us/step - loss: 0.9221 - acc: 0.5051 - val_loss: 0.8029 - val_acc: 0.4924
# Epoch 4/5
# 1186/1186 [==============================] - 0s 291us/step - loss: 0.7632 - acc: 0.5034 - val_loss: 0.7323 - val_acc: 0.4924
# Epoch 5/5
# 1186/1186 [==============================] - 0s 293us/step - loss: 0.7198 - acc: 0.5034 - val_loss: 0.7091 - val_acc: 0.5152
#
# Train results:
#
#
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# sklearn micro-F1-Score: 0.5743550834597876
#
# Test results:
#
#
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# sklearn micro-F1-Score: 0.5515151515151515
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# Predictions file written:  /home/vkolhatk/dev/constructiveness/models/CNN_C3_test_predictions1.csv

# %%
run_dl_experiment(LB_train_df, LB_test_df, model = 'lstm')
# Out:
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# Number of words not found in glove embeddings:  72
# Percentage non-zero elements:  0.9909395556658807
# Building model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 100, 300)          2417100
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 256)               439296
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,856,653
# Trainable params: 439,553
# Non-trainable params: 2,417,100
# _________________________________________________________________
# None
# Training...
# Train on 1186 samples, validate on 132 samples
# Epoch 1/5
# 1186/1186 [==============================] - 10s 8ms/step - loss: 0.6953 - acc: 0.5143 - val_loss: 0.6710 - val_acc: 0.6591
# Epoch 2/5
# 1186/1186 [==============================] - 9s 7ms/step - loss: 0.6718 - acc: 0.5826 - val_loss: 0.6588 - val_acc: 0.6742
# Epoch 3/5
# 1186/1186 [==============================] - 9s 7ms/step - loss: 0.6472 - acc: 0.6282 - val_loss: 0.6446 - val_acc: 0.6515
# Epoch 4/5
# 1186/1186 [==============================] - 9s 8ms/step - loss: 0.6100 - acc: 0.6610 - val_loss: 0.6605 - val_acc: 0.6136
# Epoch 5/5
# 1186/1186 [==============================] - 9s 7ms/step - loss: 0.6135 - acc: 0.6594 - val_loss: 0.6392 - val_acc: 0.6894
#
# Train results:
#
#
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# sklearn micro-F1-Score: 0.7253414264036417
#
# Test results:
#
#
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# sklearn micro-F1-Score: 0.6666666666666666
# len of encoded docs:  330
# Pad sequences (samples x time)
# Padded data shape: (330, 100)
# Predictions file written:  /home/vkolhatk/dev/constructiveness/models/CNN_C3_test_predictions1.csv

# %% [markdown]
# ### Experiment 4
#
# - Train: LB Train (80%)
# - Test:  C3 test (20%)

# %%
run_dl_experiment(LB_train_df, C3_test_df, model = 'cnn')
# Out:
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# Number of words not found in glove embeddings:  72
# Percentage non-zero elements:  0.9909395556658807
# Building CNN model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 100, 300)          2417100
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100, 300)          0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 98, 250)           225250
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 49, 250)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 47, 250)           187750
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 23, 250)           0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 21, 250)           187750
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 250)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 250)               62750
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_7 (Activation)    (None, 250)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 251
# _________________________________________________________________
# activation_8 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 3,080,851
# Trainable params: 3,080,851
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Train on 1186 samples, validate on 132 samples
# Epoch 1/5
# 1186/1186 [==============================] - 1s 951us/step - loss: 5.4398 - acc: 0.4646 - val_loss: 2.6855 - val_acc: 0.5076
# Epoch 2/5
# 1186/1186 [==============================] - 0s 288us/step - loss: 1.6831 - acc: 0.5034 - val_loss: 1.0588 - val_acc: 0.5076
# Epoch 3/5
# 1186/1186 [==============================] - 0s 295us/step - loss: 0.8902 - acc: 0.4933 - val_loss: 0.7826 - val_acc: 0.4924
# Epoch 4/5
# 1186/1186 [==============================] - 0s 300us/step - loss: 0.7479 - acc: 0.5042 - val_loss: 0.7217 - val_acc: 0.4924
# Epoch 5/5
# 1186/1186 [==============================] - 0s 298us/step - loss: 0.7115 - acc: 0.5051 - val_loss: 0.7037 - val_acc: 0.4924
#
# Train results:
#
#
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# sklearn micro-F1-Score: 0.503793626707132
#
# Test results:
#
#
# len of encoded docs:  1648
# Pad sequences (samples x time)
# Padded data shape: (1648, 100)
# sklearn micro-F1-Score: 0.5
# len of encoded docs:  1648
# Pad sequences (samples x time)
# Padded data shape: (1648, 100)
# Predictions file written:  /home/vkolhatk/dev/constructiveness/models/CNN_C3_test_predictions1.csv

# %%
run_dl_experiment(LB_train_df, C3_test_df, model = 'lstm')
# Out:
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# Number of words not found in glove embeddings:  72
# Percentage non-zero elements:  0.9909395556658807
# Building model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 100, 300)          2417100
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 256)               439296
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 2,856,653
# Trainable params: 439,553
# Non-trainable params: 2,417,100
# _________________________________________________________________
# None
# Training...
# Train on 1186 samples, validate on 132 samples
# Epoch 1/5
# 1186/1186 [==============================] - 10s 8ms/step - loss: 0.7028 - acc: 0.5000 - val_loss: 0.6767 - val_acc: 0.5985
# Epoch 2/5
# 1186/1186 [==============================] - 9s 7ms/step - loss: 0.6551 - acc: 0.6062 - val_loss: 0.6591 - val_acc: 0.5758
# Epoch 3/5
# 1186/1186 [==============================] - 9s 7ms/step - loss: 0.6254 - acc: 0.6610 - val_loss: 0.7134 - val_acc: 0.5758
# Epoch 4/5
# 1186/1186 [==============================] - 9s 7ms/step - loss: 0.6291 - acc: 0.6602 - val_loss: 0.6448 - val_acc: 0.6288
# Epoch 5/5
# 1186/1186 [==============================] - 9s 7ms/step - loss: 0.6012 - acc: 0.6855 - val_loss: 0.6488 - val_acc: 0.6591
#
# Train results:
#
#
# len of encoded docs:  1318
# Pad sequences (samples x time)
# Padded data shape: (1318, 100)
# sklearn micro-F1-Score: 0.7185128983308042
#
# Test results:
#
#
# len of encoded docs:  1648
# Pad sequences (samples x time)
# Padded data shape: (1648, 100)
# sklearn micro-F1-Score: 0.7026699029126213
# len of encoded docs:  1648
# Pad sequences (samples x time)
# Padded data shape: (1648, 100)
# Predictions file written:  /home/vkolhatk/dev/constructiveness/models/CNN_C3_test_predictions1.csv
